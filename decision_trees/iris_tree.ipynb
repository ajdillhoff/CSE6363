# %%
from sklearn.datasets import load_iris
from sklearn.model_selection import cross_val_score, train_test_split
from sklearn.tree import DecisionTreeClassifier
import dtreeviz

# %%
iris = load_iris()
x_train, x_test, y_train, y_test = train_test_split(iris.data, iris.target, test_size=0.10, random_state=1337)

# %%
model = DecisionTreeClassifier(max_depth=3, min_samples_leaf=10)
# model = DecisionTreeClassifier()
model.fit(x_train, y_train)
# Out:
# DecisionTreeClassifier(max_depth=3, min_samples_leaf=10)

# %%
model.score(x_train, y_train)
model.score(x_test, y_test)
# model.decision_path(x_test)
# Out:
# 1.0

# %%
tree_vis = dtreeviz.model(model, x_train, y_train, target_name="target", feature_names=iris.feature_names, class_names=list(iris.target_names))

# %%
tree_vis.view()

# %%
# Print accuracy of test set
print("Accuracy: ", model.score(x_test, y_test))
# Out:
# Accuracy:  1.0
